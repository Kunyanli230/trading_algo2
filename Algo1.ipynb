# %%
import time
import signal 
import requests
from time import sleep
import pandas
import numpy

# %%
def calculate_atr(ticker, window=14):
    payload = {'ticker': ticker}
    resp = s.get('http://localhost:9999/v1/securities/tas', params=payload)
    if not resp.ok:
        return None
    
    trades = resp.json()
    true_ranges = []

    for i in range(1, len(trades)):
        high = trades[i]['price']
        low = trades[i-1]['price']
        close = trades[i]['price']

        true_range = max(high - low, abs(high - close), abs(low - close))
        true_ranges.append(true_range)

    if len(true_ranges) < window:
        return None

    return sum(true_ranges[-window:]) / len(true_ranges[-window:])

def calculate_volatility(prices, window=10):
    if len(prices) < window:
        return None
    return sum([(p - sum(prices[-window:]) / window) ** 2 for p in prices[-window:]]) ** 0.5 / window

def adjust_risk_parameters(volatility):
    base_stop_loss = 0.02  # Minimum stop-loss percentage
    base_profit_target = 0.04  # Minimum profit-target percentage

    # Scale risk parameters with volatility
    stop_loss = base_stop_loss + (volatility * 0.5)  # Example scaling factor
    profit_target = base_profit_target + (volatility * 1.0)

    return stop_loss, profit_target


def decide_order_type(ticker, action, price, position):
    if ticker in ['CROW', 'DOVE']:  # Rebates for market orders
        order_type = 'MARKET'
    elif ticker in ['OWL', 'DUCK']:  # Rebates for limit orders
        order_type = 'LIMIT'
    else:
        order_type = 'LIMIT'  # Default to limit orders

    return {
        'ticker': ticker,
        'type': order_type,
        'quantity': ORDER_LIMIT,
        'price': price if order_type == 'LIMIT' else None,
        'action': action
    }

from math import gcd
from functools import reduce

def lcm(a, b):
    return abs(a * b) // gcd(a, b)

def calculate_lcm(prices):
    # Scale prices to integers (e.g., handle up to 2 decimal places)
    scaled_prices = [int(price * 100) for price in prices]  # Multiply by 100 to avoid floats
    lcm_scaled = reduce(lcm, scaled_prices)
    return lcm_scaled / 100  # Scale back to original form

    
def post_multiple_orders(ticker, action, total_quantity, price):
    remaining_quantity = total_quantity
    while remaining_quantity > 0:
        order_quantity = min(remaining_quantity, ORDER_LIMIT)
        s.post('http://localhost:9999/v1/orders', 
               params={'ticker': ticker, 'type': 'LIMIT', 
                       'quantity': order_quantity, 'price': price, 
                       'action': action})
        remaining_quantity -= order_quantity

# %%
s = requests.Session()
s.headers.update({'X-API-key': 'qqw'}) # Make sure you use YOUR API Key
ticker_list = ['OWL', 'CROW', 'DOVE', 'DUCK']

# global variables
MAX_LONG_EXPOSURE = 300000
MAX_SHORT_EXPOSURE = -100000
ORDER_LIMIT = 500
# Risk Management Parameters
STOP_LOSS_PERCENT = 0.05  # Exit position if price drops 5% below entry
PROFIT_TARGET_PERCENT = 0.10  # Exit position if price rises 10% above entry

# Store entry prices for each ticker
entry_prices = {}


def get_tick():
    resp = s.get('http://localhost:9999/v1/case')
    if resp.ok:
        case = resp.json()
        return case['tick'], case['status']
        
def price():
    prices = {}
    for ticker in ticker_list:
        resp = s.get(f'http://localhost:9999/v1/securities/tas?ticker={ticker}')
        if resp.ok:
            response = resp.json()
            if response:  # Ensure there's at least one trade
                prices[ticker] = response[0]['price']
                print(f'{ticker}:', prices[ticker])
            else:
                prices[ticker] = None  # No recent trades
        else:
            prices[ticker] = None  # Handle failed request
    return prices


def get_bid_ask(ticker):
    payload = {'ticker': ticker}
    resp = s.get ('http://localhost:9999/v1/securities/book', params = payload)
    if resp.ok:
        book = resp.json()
        bid_side_book = book['bids']
        ask_side_book = book['asks']
        
        bid_prices_book = [item["price"] for item in bid_side_book]
        ask_prices_book = [item['price'] for item in ask_side_book]
        
        best_bid_price = bid_prices_book[0]
        best_ask_price = ask_prices_book[0]
  
        return best_bid_price, best_ask_price

def get_time_sales(ticker):
    payload = {'ticker': ticker}
    resp = s.get ('http://localhost:9999/v1/securities/tas', params = payload)
    if resp.ok:
        book = resp.json()
        time_sales_book = [item["quantity"] for item in book]
        return time_sales_book

def get_position(ticker):
    resp = s.get('http://localhost:9999/v1/securities')
    if resp.ok:
        securities = resp.json()
        for security in securities:
            if security['ticker'] == ticker:
                return security['position']
    return 0  # Return 0 if ticker not found or request fails


def get_open_orders(ticker):
    payload = {'ticker': ticker}
    resp = s.get ('http://localhost:9999/v1/orders', params = payload)
    if resp.ok:
        orders = resp.json()
        buy_orders = [item for item in orders if item["action"] == "BUY"]
        sell_orders = [item for item in orders if item["action"] == "SELL"]
        return buy_orders, sell_orders

def get_order_status(order_id):
    resp = s.get ('http://localhost:9999/v1/orders' + '/' + str(order_id))
    if resp.ok:
        order = resp.json()
        return order['status']

def main():
    tick, status = get_tick()
    ticker_list = ['OWL', 'CROW', 'DOVE', 'DUCK']

    while status == 'ACTIVE':        
        # Fetch the latest prices for all tickers
        latest_prices = price()

        for ticker_symbol in ticker_list:
            position = get_position(ticker_symbol)
            best_bid_price, best_ask_price = get_bid_ask(ticker_symbol)
            current_price = latest_prices.get(ticker_symbol)

            if current_price is None:
                print(f"No recent trades for {ticker_symbol}. Skipping.")
                continue

            # Determine stop-loss and profit target thresholds dynamically (if enabled)
            recent_prices = get_time_sales(ticker_symbol)
            volatility = calculate_volatility(recent_prices)  # Optional: If volatility-based logic is used
            if volatility:
                stop_loss_percent, profit_target_percent = adjust_risk_parameters(volatility)
            else:
                stop_loss_percent, profit_target_percent = STOP_LOSS_PERCENT, PROFIT_TARGET_PERCENT

            print(f"Processing {ticker_symbol}: Position={position}, Current Price={current_price}")

            # Risk management: Check stop-loss and profit target
            if ticker_symbol in entry_prices and position != 0:
                entry_price = entry_prices[ticker_symbol]

                # Check stop-loss
                if position > 0 and current_price <= entry_price * (1 - stop_loss_percent):
                    print(f"Triggering stop-loss for {ticker_symbol} at {current_price}")
                    s.post('http://localhost:9999/v1/orders', 
                           params={'ticker': ticker_symbol, 'type': 'MARKET', 
                                   'quantity': abs(position), 'action': 'SELL'})
                    entry_prices.pop(ticker_symbol, None)

                # Check profit target
                elif position > 0 and current_price >= entry_price * (1 + profit_target_percent):
                    print(f"Triggering profit target for {ticker_symbol} at {current_price}")
                    s.post('http://localhost:9999/v1/orders', 
                           params={'ticker': ticker_symbol, 'type': 'MARKET', 
                                   'quantity': abs(position), 'action': 'SELL'})
                    entry_prices.pop(ticker_symbol, None)

                # For short positions
                elif position < 0 and current_price >= entry_price * (1 + stop_loss_percent):
                    print(f"Triggering stop-loss for short {ticker_symbol} at {current_price}")
                    s.post('http://localhost:9999/v1/orders', 
                           params={'ticker': ticker_symbol, 'type': 'MARKET', 
                                   'quantity': abs(position), 'action': 'BUY'})
                    entry_prices.pop(ticker_symbol, None)

                elif position < 0 and current_price <= entry_price * (1 - profit_target_percent):
                    print(f"Triggering profit target for short {ticker_symbol} at {current_price}")
                    s.post('http://localhost:9999/v1/orders', 
                           params={'ticker': ticker_symbol, 'type': 'MARKET', 
                                   'quantity': abs(position), 'action': 'BUY'})
                    entry_prices.pop(ticker_symbol, None)

            # Feebate-aware trading logic
            if position < MAX_LONG_EXPOSURE:
                order_params = decide_order_type(ticker_symbol, 'BUY', best_bid_price, position)
                print(f"Placing {order_params['type']} BUY order for {ticker_symbol}")
                s.post('http://localhost:9999/v1/orders', params=order_params)
                if ticker_symbol not in entry_prices:
                    entry_prices[ticker_symbol] = current_price

            if position > MAX_SHORT_EXPOSURE:
                order_params = decide_order_type(ticker_symbol, 'SELL', best_ask_price, position)
                print(f"Placing {order_params['type']} SELL order for {ticker_symbol}")
                s.post('http://localhost:9999/v1/orders', params=order_params)
                if ticker_symbol not in entry_prices:
                    entry_prices[ticker_symbol] = current_price

        # Cancel open orders and update market tick
        for ticker_symbol in ticker_list:
            print(f"Cancelling open orders for {ticker_symbol}")
            s.post('http://localhost:9999/v1/commands/cancel', 
                   params={'ticker': ticker_symbol})

        tick, status = get_tick()






if __name__ == '__main__':
    main()
# Out:
# OWL: 163.03
# CROW: 90.24
# DOVE: 23.78
# DUCK: 67.52
# Processing OWL: Position=0.0, Current Price=163.03
# Placing LIMIT BUY order for OWL
# Placing LIMIT SELL order for OWL
# Processing CROW: Position=0.0, Current Price=90.24
# Placing MARKET BUY order for CROW
# Placing MARKET SELL order for CROW
# Processing DOVE: Position=0.0, Current Price=23.78
# Placing MARKET BUY order for DOVE
# Placing MARKET SELL order for DOVE
# Processing DUCK: Position=0.0, Current Price=67.52
# Placing LIMIT BUY order for DUCK
# Placing LIMIT SELL order for DUCK
# Cancelling open orders for OWL
# Cancelling open orders for CROW
# Cancelling open orders for DOVE
# Cancelling open orders for DUCK
# OWL: 163.05
# CROW: 90.41
# DOVE: 23.88
# DUCK: 67.61
# Processing OWL: Position=500.0, Current Price=163.05
# Placing LIMIT BUY order for OWL
# Placing LIMIT SELL order for OWL
# Processing CROW: Position=0.0, Current Price=90.41
# Placing MARKET BUY order for CROW
# Placing MARKET SELL order for CROW
# Processing DOVE: Position=0.0, Current Price=23.88
# Placing MARKET BUY order for DOVE
# Placing MARKET SELL order for DOVE
# Processing DUCK: Position=-500.0, Current Price=67.61
# Placing LIMIT BUY order for DUCK
# Placing LIMIT SELL order for DUCK
# Cancelling open orders for OWL
# Cancelling open orders for CROW
# Cancelling open orders for DOVE
# Cancelling open orders for DUCK
# OWL: 162.48
# CROW: 90.43
# DOVE: 23.84
# DUCK: 67.69
# Processing OWL: Position=1000.0, Current Price=162.48
# Placing LIMIT BUY order for OWL
# Placing LIMIT SELL order for OWL
# Processing CROW: Position=0.0, Current Price=90.43
# Placing MARKET BUY order for CROW
# Placing MARKET SELL order for CROW
# Processing DOVE: Position=0.0, Current Price=23.84
# Placing MARKET BUY order for DOVE
# Placing MARKET SELL order for DOVE
# Processing DUCK: Position=-500.0, Current Price=67.69
# Placing LIMIT BUY order for DUCK
# Placing LIMIT SELL order for DUCK
# Cancelling open orders for OWL
# Cancelling open orders for CROW
# Cancelling open orders for DOVE
# Cancelling open orders for DUCK
# OWL: 161.95
# CROW: 90.52
# DOVE: 23.7
# DUCK: 67.77
# Processing OWL: Position=1500.0, Current Price=161.95
# Placing LIMIT BUY order for OWL
# Placing LIMIT SELL order for OWL
# Processing CROW: Position=0.0, Current Price=90.52
# Placing MARKET BUY order for CROW
# Placing MARKET SELL order for CROW
# Processing DOVE: Position=0.0, Current Price=23.7
# Placing MARKET BUY order for DOVE
# Placing MARKET SELL order for DOVE
# Processing DUCK: Position=-1000.0, Current Price=67.77
# Placing LIMIT BUY order for DUCK
# Placing LIMIT SELL order for DUCK
# Cancelling open orders for OWL
# Cancelling open orders for CROW
# Cancelling open orders for DOVE
# Cancelling open orders for DUCK
# OWL: 161.7
# CROW: 90.28
# DOVE: 23.57
# DUCK: 67.93
# Processing OWL: Position=2000.0, Current Price=161.7
# Placing LIMIT BUY order for OWL
# Placing LIMIT SELL order for OWL
# Processing CROW: Position=0.0, Current Price=90.28
# Placing MARKET BUY order for CROW
# Placing MARKET SELL order for CROW
# Processing DOVE: Position=0.0, Current Price=23.57
# Placing MARKET BUY order for DOVE
# Placing MARKET SELL order for DOVE
# Processing DUCK: Position=-1500.0, Current Price=67.93
# Placing LIMIT BUY order for DUCK
# Placing LIMIT SELL order for DUCK
# Cancelling open orders for OWL
# Cancelling open orders for CROW
# Cancelling open orders for DOVE
# Cancelling open orders for DUCK
# OWL: 161.98
# CROW: 90.09
# DOVE: 23.5
# DUCK: 68.05
# Processing OWL: Position=2000.0, Current Price=161.98
# Placing LIMIT BUY order for OWL
# Placing LIMIT SELL order for OWL
# Processing CROW: Position=0.0, Current Price=90.09
# Placing MARKET BUY order for CROW
# Placing MARKET SELL order for CROW
# Processing DOVE: Position=0.0, Current Price=23.5
# Placing MARKET BUY order for DOVE
# Placing MARKET SELL order for DOVE
# Processing DUCK: Position=-2000.0, Current Price=68.05
# Placing LIMIT BUY order for DUCK
# Placing LIMIT SELL order for DUCK
# Cancelling open orders for OWL
# Cancelling open orders for CROW
# Cancelling open orders for DOVE
# Cancelling open orders for DUCK
# OWL: 161.23
# CROW: 90.0
# DOVE: 23.68
# DUCK: 68.24
# Processing OWL: Position=2000.0, Current Price=161.23
# Placing LIMIT BUY order for OWL
# Placing LIMIT SELL order for OWL
# Processing CROW: Position=0.0, Current Price=90.0
# Placing MARKET BUY order for CROW
# Placing MARKET SELL order for CROW
# Processing DOVE: Position=0.0, Current Price=23.68
# Placing MARKET BUY order for DOVE
# Placing MARKET SELL order for DOVE
# Processing DUCK: Position=-2500.0, Current Price=68.24
# Placing LIMIT BUY order for DUCK
# Placing LIMIT SELL order for DUCK
# Cancelling open orders for OWL
# Cancelling open orders for CROW
# Cancelling open orders for DOVE
# Cancelling open orders for DUCK
# OWL: 161.27
# CROW: 90.11
# DOVE: 23.53
# DUCK: 68.49
# Processing OWL: Position=2000.0, Current Price=161.27
# Placing LIMIT BUY order for OWL
# Placing LIMIT SELL order for OWL
# Processing CROW: Position=0.0, Current Price=90.11
# Placing MARKET BUY order for CROW
# Placing MARKET SELL order for CROW
# Processing DOVE: Position=0.0, Current Price=23.53
# Placing MARKET BUY order for DOVE
# Placing MARKET SELL order for DOVE
# Processing DUCK: Position=-3000.0, Current Price=68.49
# Placing LIMIT BUY order for DUCK
# Placing LIMIT SELL order for DUCK
# Cancelling open orders for OWL
# Cancelling open orders for CROW
# Cancelling open orders for DOVE
# Cancelling open orders for DUCK
# OWL: 161.46
# CROW: 90.28
# DOVE: 23.91
# DUCK: 68.79
# Processing OWL: Position=2000.0, Current Price=161.46
# Placing LIMIT BUY order for OWL
# Placing LIMIT SELL order for OWL
# Processing CROW: Position=0.0, Current Price=90.28
# Placing MARKET BUY order for CROW
# Placing MARKET SELL order for CROW
# Processing DOVE: Position=0.0, Current Price=23.91
# Placing MARKET BUY order for DOVE
# Placing MARKET SELL order for DOVE
# Processing DUCK: Position=-3500.0, Current Price=68.79
# Placing LIMIT BUY order for DUCK
# Placing LIMIT SELL order for DUCK
# Cancelling open orders for OWL
# Cancelling open orders for CROW
# Cancelling open orders for DOVE
# Cancelling open orders for DUCK
# OWL: 161.85
# CROW: 90.59
# DOVE: 23.54
# DUCK: 68.54
# Processing OWL: Position=2000.0, Current Price=161.85
# Placing LIMIT BUY order for OWL
# Placing LIMIT SELL order for OWL
# Processing CROW: Position=0.0, Current Price=90.59
# Placing MARKET BUY order for CROW
# Placing MARKET SELL order for CROW
# Processing DOVE: Position=0.0, Current Price=23.54
# Placing MARKET BUY order for DOVE
# Placing MARKET SELL order for DOVE
# Processing DUCK: Position=-3000.0, Current Price=68.54
# Placing LIMIT BUY order for DUCK
# Placing LIMIT SELL order for DUCK
# Cancelling open orders for OWL
# Cancelling open orders for CROW
# Cancelling open orders for DOVE
# Cancelling open orders for DUCK
# OWL: 162.14
# CROW: 90.63
# DOVE: 23.45
# DUCK: 68.49
# Processing OWL: Position=2000.0, Current Price=162.14
# Placing LIMIT BUY order for OWL
# Placing LIMIT SELL order for OWL
# Processing CROW: Position=0.0, Current Price=90.63
# Placing MARKET BUY order for CROW
# Placing MARKET SELL order for CROW
# Processing DOVE: Position=0.0, Current Price=23.45
# Placing MARKET BUY order for DOVE
# Placing MARKET SELL order for DOVE
# Processing DUCK: Position=-2500.0, Current Price=68.49
# Placing LIMIT BUY order for DUCK
# Placing LIMIT SELL order for DUCK
# Cancelling open orders for OWL
# Cancelling open orders for CROW
# Cancelling open orders for DOVE
# Cancelling open orders for DUCK
# OWL: 161.41
# CROW: 90.69
# DOVE: 23.43
# DUCK: 68.85
# Processing OWL: Position=2500.0, Current Price=161.41
# Placing LIMIT BUY order for OWL
# Placing LIMIT SELL order for OWL
# Processing CROW: Position=0.0, Current Price=90.69
# Placing MARKET BUY order for CROW
# Placing MARKET SELL order for CROW
# Processing DOVE: Position=0.0, Current Price=23.43
# Placing MARKET BUY order for DOVE
# Placing MARKET SELL order for DOVE
# Processing DUCK: Position=-3000.0, Current Price=68.85
# Placing LIMIT BUY order for DUCK
# Placing LIMIT SELL order for DUCK
# Cancelling open orders for OWL
# Cancelling open orders for CROW
# Cancelling open orders for DOVE
# Cancelling open orders for DUCK
# OWL: 161.01
# CROW: 90.77
# DOVE: 23.33
# DUCK: 68.5
# Processing OWL: Position=2500.0, Current Price=161.01
# Placing LIMIT BUY order for OWL
# Placing LIMIT SELL order for OWL
# Processing CROW: Position=0.0, Current Price=90.77
# Placing MARKET BUY order for CROW
# Placing MARKET SELL order for CROW
# Processing DOVE: Position=0.0, Current Price=23.33
# Placing MARKET BUY order for DOVE
# Placing MARKET SELL order for DOVE
# Processing DUCK: Position=-3000.0, Current Price=68.5
# Placing LIMIT BUY order for DUCK
# Placing LIMIT SELL order for DUCK
# Cancelling open orders for OWL
# Cancelling open orders for CROW
# Cancelling open orders for DOVE
# Cancelling open orders for DUCK
# OWL: 161.25
# CROW: 90.93
# DOVE: 23.37
# DUCK: 68.74
# Processing OWL: Position=2500.0, Current Price=161.25
# Placing LIMIT BUY order for OWL
# Placing LIMIT SELL order for OWL
# Processing CROW: Position=0.0, Current Price=90.93
# Placing MARKET BUY order for CROW
# Placing MARKET SELL order for CROW
# Processing DOVE: Position=0.0, Current Price=23.37
# Placing MARKET BUY order for DOVE
# Placing MARKET SELL order for DOVE
# Processing DUCK: Position=-3000.0, Current Price=68.74
# Placing LIMIT BUY order for DUCK
# Placing LIMIT SELL order for DUCK
# Cancelling open orders for OWL
# Cancelling open orders for CROW
# Cancelling open orders for DOVE
# Cancelling open orders for DUCK
# OWL: 160.53
# CROW: 90.96
# DOVE: 23.37
# DUCK: 68.37
# Processing OWL: Position=2500.0, Current Price=160.53
# Placing LIMIT BUY order for OWL
# Placing LIMIT SELL order for OWL
# Processing CROW: Position=0.0, Current Price=90.96
# Placing MARKET BUY order for CROW
# Placing MARKET SELL order for CROW
# Processing DOVE: Position=0.0, Current Price=23.37
# Placing MARKET BUY order for DOVE
# Placing MARKET SELL order for DOVE
# Processing DUCK: Position=-2500.0, Current Price=68.37
# Placing LIMIT BUY order for DUCK
# Placing LIMIT SELL order for DUCK
# Cancelling open orders for OWL
# Cancelling open orders for CROW
# Cancelling open orders for DOVE
# Cancelling open orders for DUCK
# OWL: 160.4
# CROW: 91.07
# DOVE: 23.4
# DUCK: 68.6
# Processing OWL: Position=2000.0, Current Price=160.4
# Placing LIMIT BUY order for OWL
# Placing LIMIT SELL order for OWL
# Processing CROW: Position=0.0, Current Price=91.07
# Placing MARKET BUY order for CROW
# Placing MARKET SELL order for CROW
# Processing DOVE: Position=0.0, Current Price=23.4
# Placing MARKET BUY order for DOVE
# Placing MARKET SELL order for DOVE
# Processing DUCK: Position=-2500.0, Current Price=68.6
# Placing LIMIT BUY order for DUCK
# Placing LIMIT SELL order for DUCK
# Cancelling open orders for OWL
# Cancelling open orders for CROW
# Cancelling open orders for DOVE
# Cancelling open orders for DUCK
# OWL: 160.01
# CROW: 91.13
# DOVE: 23.16
# DUCK: 68.34
# Processing OWL: Position=2500.0, Current Price=160.01
# Placing LIMIT BUY order for OWL
# Placing LIMIT SELL order for OWL
# Processing CROW: Position=0.0, Current Price=91.13
# Placing MARKET BUY order for CROW
# Placing MARKET SELL order for CROW
# Processing DOVE: Position=0.0, Current Price=23.16
# Placing MARKET BUY order for DOVE
# Placing MARKET SELL order for DOVE
# Processing DUCK: Position=-2500.0, Current Price=68.34
# Placing LIMIT BUY order for DUCK
# Placing LIMIT SELL order for DUCK
# Cancelling open orders for OWL
# Cancelling open orders for CROW
# Cancelling open orders for DOVE
# Cancelling open orders for DUCK
# OWL: 159.7
# CROW: 91.3
# DOVE: 23.3
# DUCK: 68.92
# Processing OWL: Position=3000.0, Current Price=159.7
# Placing LIMIT BUY order for OWL
# Placing LIMIT SELL order for OWL
# Processing CROW: Position=0.0, Current Price=91.3
# Placing MARKET BUY order for CROW
# Placing MARKET SELL order for CROW
# Processing DOVE: Position=0.0, Current Price=23.3
# Placing MARKET BUY order for DOVE
# Placing MARKET SELL order for DOVE
# Processing DUCK: Position=-2500.0, Current Price=68.92
# Placing LIMIT BUY order for DUCK
# Placing LIMIT SELL order for DUCK
# Cancelling open orders for OWL
# Cancelling open orders for CROW
# Cancelling open orders for DOVE
# Cancelling open orders for DUCK
# OWL: 159.77
# CROW: 91.55
# DOVE: 23.11
# DUCK: 68.62
# Processing OWL: Position=2500.0, Current Price=159.77
# Placing LIMIT BUY order for OWL
# Placing LIMIT SELL order for OWL
# Processing CROW: Position=0.0, Current Price=91.55
# Placing MARKET BUY order for CROW
# Placing MARKET SELL order for CROW
# Processing DOVE: Position=0.0, Current Price=23.11
# Placing MARKET BUY order for DOVE
# Placing MARKET SELL order for DOVE
# Processing DUCK: Position=-2000.0, Current Price=68.62
# Placing LIMIT BUY order for DUCK
# Placing LIMIT SELL order for DUCK
# Cancelling open orders for OWL
# Cancelling open orders for CROW
# Cancelling open orders for DOVE
# Cancelling open orders for DUCK
# OWL: 159.27
# CROW: 91.66
# DOVE: 23.09
# DUCK: 68.94
# Processing OWL: Position=2500.0, Current Price=159.27
# Placing LIMIT BUY order for OWL
# Placing LIMIT SELL order for OWL
# Processing CROW: Position=0.0, Current Price=91.66
# Placing MARKET BUY order for CROW
# Placing MARKET SELL order for CROW
# Processing DOVE: Position=0.0, Current Price=23.09
# Placing MARKET BUY order for DOVE
# Placing MARKET SELL order for DOVE
# Processing DUCK: Position=-2500.0, Current Price=68.94
# Placing LIMIT BUY order for DUCK
# Placing LIMIT SELL order for DUCK
# Cancelling open orders for OWL
# Cancelling open orders for CROW
# Cancelling open orders for DOVE
# Cancelling open orders for DUCK
# OWL: 159.73
# CROW: 91.78
# DOVE: 22.91
# DUCK: 68.57
# Processing OWL: Position=2000.0, Current Price=159.73
# Placing LIMIT BUY order for OWL
# Placing LIMIT SELL order for OWL
# Processing CROW: Position=0.0, Current Price=91.78
# Placing MARKET BUY order for CROW
# Placing MARKET SELL order for CROW
# Processing DOVE: Position=0.0, Current Price=22.91
# Placing MARKET BUY order for DOVE
# Placing MARKET SELL order for DOVE
# Processing DUCK: Position=-2000.0, Current Price=68.57
# Placing LIMIT BUY order for DUCK
# Placing LIMIT SELL order for DUCK
# Cancelling open orders for OWL
# Cancelling open orders for CROW
# Cancelling open orders for DOVE
# Cancelling open orders for DUCK
# OWL: 159.36
# CROW: 92.05
# DOVE: 22.77
# DUCK: 68.59
# Processing OWL: Position=1500.0, Current Price=159.36
# Placing LIMIT BUY order for OWL
# Placing LIMIT SELL order for OWL
# Processing CROW: Position=0.0, Current Price=92.05
# Placing MARKET BUY order for CROW
# Placing MARKET SELL order for CROW
# Processing DOVE: Position=0.0, Current Price=22.77
# Placing MARKET BUY order for DOVE
# Placing MARKET SELL order for DOVE
# Processing DUCK: Position=-2500.0, Current Price=68.59
# Placing LIMIT BUY order for DUCK
# Placing LIMIT SELL order for DUCK
# Cancelling open orders for OWL
# Cancelling open orders for CROW
# Cancelling open orders for DOVE
# Cancelling open orders for DUCK
# OWL: 160.47
# CROW: 92.06
# DOVE: 22.84
# DUCK: 68.97
# Processing OWL: Position=1000.0, Current Price=160.47
# Placing LIMIT BUY order for OWL
# Placing LIMIT SELL order for OWL
# Processing CROW: Position=0.0, Current Price=92.06
# Placing MARKET BUY order for CROW
# Placing MARKET SELL order for CROW
# Processing DOVE: Position=0.0, Current Price=22.84
# Placing MARKET BUY order for DOVE
# Placing MARKET SELL order for DOVE
# Processing DUCK: Position=-3000.0, Current Price=68.97
# Placing LIMIT BUY order for DUCK
# Placing LIMIT SELL order for DUCK
# Cancelling open orders for OWL
# Cancelling open orders for CROW
# Cancelling open orders for DOVE
# Cancelling open orders for DUCK
# OWL: 160.37
# CROW: 92.26
# DOVE: 22.77
# DUCK: 69.03
# Processing OWL: Position=1000.0, Current Price=160.37
# Placing LIMIT BUY order for OWL
# Placing LIMIT SELL order for OWL
# Processing CROW: Position=0.0, Current Price=92.26
# Placing MARKET BUY order for CROW
# Placing MARKET SELL order for CROW
# Processing DOVE: Position=0.0, Current Price=22.77
# Placing MARKET BUY order for DOVE
# Placing MARKET SELL order for DOVE
# Processing DUCK: Position=-3000.0, Current Price=69.03
# Placing LIMIT BUY order for DUCK
# Placing LIMIT SELL order for DUCK
# Cancelling open orders for OWL
# Cancelling open orders for CROW
# Cancelling open orders for DOVE
# Cancelling open orders for DUCK
# OWL: 160.62
# CROW: 92.35
# DOVE: 22.39
# DUCK: 68.53
# Processing OWL: Position=500.0, Current Price=160.62
# Placing LIMIT BUY order for OWL
# Placing LIMIT SELL order for OWL
# Processing CROW: Position=0.0, Current Price=92.35
# Placing MARKET BUY order for CROW
# Placing MARKET SELL order for CROW
# Processing DOVE: Position=0.0, Current Price=22.39
# Placing MARKET BUY order for DOVE
# Placing MARKET SELL order for DOVE
# Processing DUCK: Position=-2500.0, Current Price=68.53
# Placing LIMIT BUY order for DUCK
# Placing LIMIT SELL order for DUCK
# Cancelling open orders for OWL
# Cancelling open orders for CROW
# Cancelling open orders for DOVE
# Cancelling open orders for DUCK
# OWL: 160.12
# CROW: 92.59
# DOVE: 22.26
# DUCK: 68.25
# Processing OWL: Position=500.0, Current Price=160.12
# Placing LIMIT BUY order for OWL
# Placing LIMIT SELL order for OWL
# Processing CROW: Position=0.0, Current Price=92.59
# Placing MARKET BUY order for CROW
# Placing MARKET SELL order for CROW
# Processing DOVE: Position=0.0, Current Price=22.26
# Placing MARKET BUY order for DOVE
# Placing MARKET SELL order for DOVE
# Processing DUCK: Position=-2000.0, Current Price=68.25
# Placing LIMIT BUY order for DUCK
# Placing LIMIT SELL order for DUCK
# Cancelling open orders for OWL
# Cancelling open orders for CROW
# Cancelling open orders for DOVE
# Cancelling open orders for DUCK
# OWL: 160.7
# CROW: 92.72
# DOVE: 22.59
# DUCK: 68.2
# Processing OWL: Position=0.0, Current Price=160.7
# Placing LIMIT BUY order for OWL
# Placing LIMIT SELL order for OWL
# Processing CROW: Position=0.0, Current Price=92.72
# Placing MARKET BUY order for CROW
# Placing MARKET SELL order for CROW
# Processing DOVE: Position=0.0, Current Price=22.59
# Placing MARKET BUY order for DOVE
# Placing MARKET SELL order for DOVE
# Processing DUCK: Position=-2000.0, Current Price=68.2
# Placing LIMIT BUY order for DUCK
# Placing LIMIT SELL order for DUCK
# Cancelling open orders for OWL
# Cancelling open orders for CROW
# Cancelling open orders for DOVE
# Cancelling open orders for DUCK
# OWL: 160.71
# CROW: 92.83
# DOVE: 22.53
# DUCK: 68.46
# Processing OWL: Position=-500.0, Current Price=160.71
# Placing LIMIT BUY order for OWL
# Placing LIMIT SELL order for OWL
# Processing CROW: Position=0.0, Current Price=92.83
# Placing MARKET BUY order for CROW
# Placing MARKET SELL order for CROW
# Processing DOVE: Position=0.0, Current Price=22.53
# Placing MARKET BUY order for DOVE
# Placing MARKET SELL order for DOVE
# Processing DUCK: Position=-1500.0, Current Price=68.46
# Placing LIMIT BUY order for DUCK
# Placing LIMIT SELL order for DUCK
# Cancelling open orders for OWL
# Cancelling open orders for CROW
# Cancelling open orders for DOVE
# Cancelling open orders for DUCK
# OWL: 160.87
# CROW: 92.93
# DOVE: 22.47
# DUCK: 68.35
# Processing OWL: Position=-1000.0, Current Price=160.87
# Placing LIMIT BUY order for OWL
# Placing LIMIT SELL order for OWL
# Processing CROW: Position=0.0, Current Price=92.93
# Placing MARKET BUY order for CROW
# Placing MARKET SELL order for CROW
# Processing DOVE: Position=0.0, Current Price=22.47
# Placing MARKET BUY order for DOVE
# Placing MARKET SELL order for DOVE
# Processing DUCK: Position=-1500.0, Current Price=68.35
# Placing LIMIT BUY order for DUCK
# Placing LIMIT SELL order for DUCK
# Cancelling open orders for OWL
# Cancelling open orders for CROW
# Cancelling open orders for DOVE
# Cancelling open orders for DUCK
# OWL: 161.11
# CROW: 92.79
# DOVE: 22.19
# DUCK: 68.25
# Processing OWL: Position=-1000.0, Current Price=161.11
# Placing LIMIT BUY order for OWL
# Placing LIMIT SELL order for OWL
# Processing CROW: Position=0.0, Current Price=92.79
# Placing MARKET BUY order for CROW
# Placing MARKET SELL order for CROW
# Processing DOVE: Position=0.0, Current Price=22.19
# Placing MARKET BUY order for DOVE
# Placing MARKET SELL order for DOVE
# Processing DUCK: Position=-1000.0, Current Price=68.25
# Placing LIMIT BUY order for DUCK
# Placing LIMIT SELL order for DUCK
# Cancelling open orders for OWL
# Cancelling open orders for CROW
# Cancelling open orders for DOVE
# Cancelling open orders for DUCK
# OWL: 161.54
# CROW: 92.55
# DOVE: 22.56
# DUCK: 68.44
# Processing OWL: Position=-1000.0, Current Price=161.54
# Placing LIMIT BUY order for OWL
# Placing LIMIT SELL order for OWL
# Processing CROW: Position=0.0, Current Price=92.55
# Placing MARKET BUY order for CROW
# Placing MARKET SELL order for CROW
# Processing DOVE: Position=0.0, Current Price=22.56
# Placing MARKET BUY order for DOVE
# Placing MARKET SELL order for DOVE
# Processing DUCK: Position=-1000.0, Current Price=68.44
# Placing LIMIT BUY order for DUCK
# Placing LIMIT SELL order for DUCK
# Cancelling open orders for OWL
# Cancelling open orders for CROW
# Cancelling open orders for DOVE
# Cancelling open orders for DUCK
# OWL: 161.64
# CROW: 92.89
# DOVE: 22.07
# DUCK: 68.36
# Processing OWL: Position=-1000.0, Current Price=161.64
# Placing LIMIT BUY order for OWL
# Placing LIMIT SELL order for OWL
# Processing CROW: Position=0.0, Current Price=92.89
# Placing MARKET BUY order for CROW
# Placing MARKET SELL order for CROW
# Processing DOVE: Position=0.0, Current Price=22.07
# Placing MARKET BUY order for DOVE
# Placing MARKET SELL order for DOVE
# Processing DUCK: Position=-1000.0, Current Price=68.36
# Placing LIMIT BUY order for DUCK
# Placing LIMIT SELL order for DUCK
# Cancelling open orders for OWL
# Cancelling open orders for CROW
# Cancelling open orders for DOVE
# Cancelling open orders for DUCK
# OWL: 161.64
# CROW: 92.85
# DOVE: 22.15
# DUCK: 68.21
# Processing OWL: Position=-1500.0, Current Price=161.64
# Placing LIMIT BUY order for OWL
# Placing LIMIT SELL order for OWL
# Processing CROW: Position=0.0, Current Price=92.85
# Placing MARKET BUY order for CROW
# Placing MARKET SELL order for CROW
# Processing DOVE: Position=0.0, Current Price=22.15
# Placing MARKET BUY order for DOVE
# Placing MARKET SELL order for DOVE
# Processing DUCK: Position=-1000.0, Current Price=68.21
# Placing LIMIT BUY order for DUCK
# Placing LIMIT SELL order for DUCK
# Cancelling open orders for OWL
# Cancelling open orders for CROW
# Cancelling open orders for DOVE
# Cancelling open orders for DUCK
# OWL: 162.12
# CROW: 92.96
# DOVE: 22.25
# DUCK: 68.75
# Processing OWL: Position=-2000.0, Current Price=162.12
# Placing LIMIT BUY order for OWL
# Placing LIMIT SELL order for OWL
# Processing CROW: Position=0.0, Current Price=92.96
# Placing MARKET BUY order for CROW
# Placing MARKET SELL order for CROW
# Processing DOVE: Position=0.0, Current Price=22.25
# Placing MARKET BUY order for DOVE
# Placing MARKET SELL order for DOVE
# Processing DUCK: Position=-1500.0, Current Price=68.75
# Placing LIMIT BUY order for DUCK
# Placing LIMIT SELL order for DUCK
# Cancelling open orders for OWL
# Cancelling open orders for CROW
# Cancelling open orders for DOVE
# Cancelling open orders for DUCK
# OWL: 162.2
# CROW: 93.02
# DOVE: 22.27
# DUCK: 68.78
# Processing OWL: Position=-2500.0, Current Price=162.2
# Placing LIMIT BUY order for OWL
# Placing LIMIT SELL order for OWL
# Processing CROW: Position=0.0, Current Price=93.02
# Placing MARKET BUY order for CROW
# Placing MARKET SELL order for CROW
# Processing DOVE: Position=0.0, Current Price=22.27
# Placing MARKET BUY order for DOVE
# Placing MARKET SELL order for DOVE
# Processing DUCK: Position=-2000.0, Current Price=68.78
# Placing LIMIT BUY order for DUCK
# Placing LIMIT SELL order for DUCK
# Cancelling open orders for OWL
# Cancelling open orders for CROW
# Cancelling open orders for DOVE
# Cancelling open orders for DUCK
# OWL: 162.54
# CROW: 93.11
# DOVE: 22.62
# DUCK: 69.01
# Processing OWL: Position=-3000.0, Current Price=162.54
# Placing LIMIT BUY order for OWL
# Placing LIMIT SELL order for OWL
# Processing CROW: Position=0.0, Current Price=93.11
# Placing MARKET BUY order for CROW
# Placing MARKET SELL order for CROW
# Processing DOVE: Position=0.0, Current Price=22.62
# Placing MARKET BUY order for DOVE
# Placing MARKET SELL order for DOVE
# Processing DUCK: Position=-2500.0, Current Price=69.01
# Placing LIMIT BUY order for DUCK
# Placing LIMIT SELL order for DUCK
# Cancelling open orders for OWL
# Cancelling open orders for CROW
# Cancelling open orders for DOVE
# Cancelling open orders for DUCK
# OWL: 162.62
# CROW: 93.18
# DOVE: 22.09
# DUCK: 68.8
# Processing OWL: Position=-3500.0, Current Price=162.62
# Placing LIMIT BUY order for OWL
# Placing LIMIT SELL order for OWL
# Processing CROW: Position=0.0, Current Price=93.18
# Placing MARKET BUY order for CROW
# Placing MARKET SELL order for CROW
# Processing DOVE: Position=0.0, Current Price=22.09
# Placing MARKET BUY order for DOVE
# Placing MARKET SELL order for DOVE
# Processing DUCK: Position=-2000.0, Current Price=68.8
# Placing LIMIT BUY order for DUCK
# Placing LIMIT SELL order for DUCK
# Cancelling open orders for OWL
# Cancelling open orders for CROW
# Cancelling open orders for DOVE
# Cancelling open orders for DUCK
# OWL: 163.02
# CROW: 93.32
# DOVE: 22.62
# DUCK: 69.06
# Processing OWL: Position=-4000.0, Current Price=163.02
# Placing LIMIT BUY order for OWL
# Placing LIMIT SELL order for OWL
# Processing CROW: Position=0.0, Current Price=93.32
# Placing MARKET BUY order for CROW
# Placing MARKET SELL order for CROW
# Processing DOVE: Position=0.0, Current Price=22.62
# Placing MARKET BUY order for DOVE
# Placing MARKET SELL order for DOVE
# Processing DUCK: Position=-2500.0, Current Price=69.06
# Placing LIMIT BUY order for DUCK
# Placing LIMIT SELL order for DUCK
# Cancelling open orders for OWL
# Cancelling open orders for CROW
# Cancelling open orders for DOVE
# Cancelling open orders for DUCK
# OWL: 162.47
# CROW: 93.4
# DOVE: 22.09
# DUCK: 68.69
# Processing OWL: Position=-4000.0, Current Price=162.47
# Placing LIMIT BUY order for OWL
# Placing LIMIT SELL order for OWL
# Processing CROW: Position=0.0, Current Price=93.4
# Placing MARKET BUY order for CROW
# Placing MARKET SELL order for CROW
# Processing DOVE: Position=0.0, Current Price=22.09
# Placing MARKET BUY order for DOVE
# Placing MARKET SELL order for DOVE
# Processing DUCK: Position=-2000.0, Current Price=68.69
# Placing LIMIT BUY order for DUCK
# Placing LIMIT SELL order for DUCK
# Cancelling open orders for OWL
# Cancelling open orders for CROW
# Cancelling open orders for DOVE
# Cancelling open orders for DUCK
# OWL: 162.55
# CROW: 93.61
# DOVE: 22.52
# DUCK: 68.62
# Processing OWL: Position=-4000.0, Current Price=162.55
# Placing LIMIT BUY order for OWL
# Placing LIMIT SELL order for OWL
# Processing CROW: Position=0.0, Current Price=93.61
# Placing MARKET BUY order for CROW
# Placing MARKET SELL order for CROW
# Processing DOVE: Position=0.0, Current Price=22.52
# Placing MARKET BUY order for DOVE
# Placing MARKET SELL order for DOVE
# Processing DUCK: Position=-2000.0, Current Price=68.62
# Placing LIMIT BUY order for DUCK
# Placing LIMIT SELL order for DUCK
# Cancelling open orders for OWL
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 179
#     171         tick, status = get_tick()
#     178 if __name__ == '__main__':
# --> 179     main()
#
# Cell In[5], line 168, in main()
#     166 for ticker_symbol in ticker_list:
#     167     print(f"Cancelling open orders for {ticker_symbol}")
# --> 168     s.post('http://localhost:9999/v1/commands/cancel',
#     169            params={'ticker': ticker_symbol})
#     171 tick, status = get_tick()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\sessions.py:637, in Session.post(self, url, data, json, **kwargs)
#     626 def post(self, url, data=None, json=None, **kwargs):
#     627     r"""Sends a POST request. Returns :class:`Response` object.
#     628
#     629     :param url: URL for the new :class:`Request` object.
#    (...)
#     634     :rtype: requests.Response
#     635     """
# --> 637     return self.request("POST", url, data=data, json=json, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 response_conn = conn if not release_conn else None
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#     805 clean_exit = True
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connection.py:464, in HTTPConnection.getresponse(self)
#     461 from .response import HTTPResponse
#     463 # Get the response from http.client.HTTPConnection
# --> 464 httplib_response = super().getresponse()
#     466 try:
#     467     assert_header_parsing(httplib_response.msg)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\http\client.py:1428, in HTTPConnection.getresponse(self)
#    1426 try:
#    1427     try:
# -> 1428         response.begin()
#    1429     except ConnectionError:
#    1430         self.close()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\http\client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\http\client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\socket.py:720, in SocketIO.readinto(self, b)
#     718 while True:
#     719     try:
# --> 720         return self._sock.recv_into(b)
#     721     except timeout:
#     722         self._timeout_occurred = True
#
# KeyboardInterrupt:
